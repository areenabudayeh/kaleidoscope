# %% [markdown]
# ### Getting to know the data

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('data.xlsx')
data.head()
# Out:
#    sequence Episode 1  ID Episode 1 Runtime Episode 1  \
# 0      1806      Pink       4069937               56m
# 1      9254    Yellow       3483983               49m
# 2     31441    Orange       4069935               52m
# 3     18465      Blue       4069266               48m
# 4     34383    Violet       4069934               49m
#
#        Time period Episode 1  \
# 0   6 Months After the Heist
# 1   6 Weeks Before the Heist
# 2   3 Weeks Before the Heist
# 3    5 Days Before the Heist
# 4  24 Years Before the Heist
#
#                                     Genres Episode 1  Rating Episode 1  \
# 0  {'drama': 0.41, 'thriller': 0.32, 'action': 0.27}               7.5
# 1  {'drama': 0.13, 'thriller': 0.39, 'action': 0.48}               7.0
# 2  {'drama': 0.71, 'thriller': 0.14, 'action': 0.14}               7.1
# 3  {'drama': 0.56, 'thriller': 0.33, 'action': 0.11}               7.2
# 4   {'drama': 0.71, 'thriller': 0.1, 'action': 0.19}               7.5
#
# ...

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
# rows and columns
data.shape
# Out:
# (30320, 53)

# %%
# Features
data.columns
# Out:
# Index(['sequence', 'Episode 1', 'ID Episode 1', 'Runtime Episode 1',
#        'Time period Episode 1', 'Genres Episode 1', 'Rating Episode 1',
#        'Episode 2', 'ID Episode 2', 'Runtime Episode 2',
#        'Time period Episode 2', 'Genres Episode 2', 'Rating Episode 2',
#        'Episode 3', 'ID Episode 3', 'Runtime Episode 3',
#        'Time period Episode 3', 'Genres Episode 3', 'Rating Episode 3',
#        'Episode 4', 'ID Episode 4', 'Runtime Episode 4',
#        'Time period Episode 4', 'Genres Episode 4', 'Rating Episode 4',
#        'Episode 5', 'ID Episode 5', 'Runtime Episode 5',
#        'Time period Episode 5', 'Genres Episode 5', 'Rating Episode 5',
#        'Episode 6', 'ID Episode 6', 'Runtime Episode 6',
#        'Time period Episode 6', 'Genres Episode 6', 'Rating Episode 6',
#        'Episode 7', 'ID Episode 7', 'Runtime Episode 7',
#        'Time period Episode 7', 'Genres Episode 7', 'Rating Episode 7',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30320 entries, 0 to 30319
# Data columns (total 53 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sequence               30320 non-null  int64
#  1   Episode 1              30320 non-null  object
#  2   ID Episode 1           30320 non-null  int64
#  3   Runtime Episode 1      30320 non-null  object
#  4   Time period Episode 1  30320 non-null  object
#  5   Genres Episode 1       30320 non-null  object
#  6   Rating Episode 1       30320 non-null  float64
#  7   Episode 2              30320 non-null  object
#  8   ID Episode 2           30320 non-null  int64
#  9   Runtime Episode 2      30320 non-null  object
#  10  Time period Episode 2  30320 non-null  object
#  11  Genres Episode 2       30320 non-null  object
#  12  Rating Episode 2       30320 non-null  float64
#  13  Episode 3              30320 non-null  object
# ...

# %%
# No missing values
data.isnull().sum()
# Out:
# sequence                 0
# Episode 1                0
# ID Episode 1             0
# Runtime Episode 1        0
# Time period Episode 1    0
# Genres Episode 1         0
# Rating Episode 1         0
# Episode 2                0
# ID Episode 2             0
# Runtime Episode 2        0
# Time period Episode 2    0
# Genres Episode 2         0
# Rating Episode 2         0
# Episode 3                0
# ID Episode 3             0
# Runtime Episode 3        0
# Time period Episode 3    0
# Genres Episode 3         0
# Rating Episode 3         0
# Episode 4                0
# ID Episode 4             0
# Runtime Episode 4        0
# Time period Episode 4    0
# Genres Episode 4         0
# Rating Episode 4         0
# Episode 5                0
# ID Episode 5             0
# Runtime Episode 5        0
# Time period Episode 5    0
# Genres Episode 5         0
# Rating Episode 5         0
# Episode 6                0
# ID Episode 6             0
# Runtime Episode 6        0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# Visualize missing values using a heatmap

custom_cmap = LinearSegmentedColormap.from_list("custom_pistachio", [ "#95bfb2","white"])

plt.figure(figsize=(10, 6))
sns.heatmap(data.isnull(), cmap=custom_cmap, cbar=False)
plt.title('Missing Values Heatmap', fontsize=14)
plt.show()

# %%
# Find duplicate rows
duplicates = data[data.duplicated()]
print(f"Number of duplicate rows: {duplicates.shape[0]}")
# Out:
# Number of duplicate rows: 0

# %%
# Check for unique values in categorical columns to see if any unexpected categories exist
for column in data.select_dtypes(include=['object']).columns:
    print(f'Unique values in {column}:')
    print(data[column].value_counts())
    print('\n')
# Out:
# Unique values in Episode 1:
# Episode 1
# White     3858
# Green     3824
# Orange    3818
# Pink      3817
# Yellow    3776
# Violet    3759
# Red       3743
# Blue      3725
# Name: count, dtype: int64
#
#
# Unique values in Runtime Episode 1:
# Runtime Episode 1
# 48m    7583
# 49m    7535
# 46m    3824
# 52m    3818
# 56m    3817
# 36m    3743
# Name: count, dtype: int64
#
#
# Unique values in Time period Episode 1:
# Time period Episode 1
# The Heist                      3858
# 7 Years Before the Heist       3824
# 3 Weeks Before the Heist       3818
# 6 Months After the Heist       3817
# 6 Weeks Before the Heist       3776
# 24 Years Before the Heist      3759
# The Morning After the Heist    3743
# 5 Days Before the Heist        3725
# Name: count, dtype: int64
#
#
# Unique values in Genres Episode 1:
# Genres Episode 1
# {'drama': 0.21, 'thriller': 0.32, 'action': 0.47}    3858
# {'drama': 0.45, 'thriller': 0.15, 'action': 0.4}     3824
# ...

# %%
for i in range(1, 9):
    episode_column = f'Episode {i}'
    print(data[episode_column].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0          Pink
# 1        Yellow
# 2        Orange
# 3          Blue
# 4        Violet
#           ...
# 30315    Yellow
# 30316    Orange
# 30317    Orange
# 30318    Orange
# 30319      Blue
# Name: Episode 1, Length: 30320, dtype: object>
# <bound method IndexOpsMixin.value_counts of 0           Red
# 1          Pink
# 2        Yellow
# 3           Red
# 4           Red
#           ...
# 30315      Blue
# 30316     Green
# 30317     Green
# 30318     Green
# 30319    Orange
# Name: Episode 2, Length: 30320, dtype: object>
# <bound method IndexOpsMixin.value_counts of 0        Violet
# 1         Green
# 2         Green
# 3         White
# 4        Yellow
#           ...
# 30315     Green
# 30316      Pink
# 30317      Pink
# 30318      Blue
# 30319       Red
# Name: Episode 3, Length: 30320, dtype: object>
# <bound method IndexOpsMixin.value_counts of 0         Green
# 1        Violet
# 2         White
# 3         Green
# ...

# %%
for i in range(1, 9):
    time_period_column = f'Time period Episode {i}'
    print(data[time_period_column].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0         6 Months After the Heist
# 1         6 Weeks Before the Heist
# 2         3 Weeks Before the Heist
# 3          5 Days Before the Heist
# 4        24 Years Before the Heist
#                    ...
# 30315     6 Weeks Before the Heist
# 30316     3 Weeks Before the Heist
# 30317     3 Weeks Before the Heist
# 30318     3 Weeks Before the Heist
# 30319      5 Days Before the Heist
# Name: Time period Episode 1, Length: 30320, dtype: object>
# <bound method IndexOpsMixin.value_counts of 0        The Morning After the Heist
# 1           6 Months After the Heist
# 2           6 Weeks Before the Heist
# 3        The Morning After the Heist
# 4        The Morning After the Heist
#                     ...
# 30315        5 Days Before the Heist
# 30316       7 Years Before the Heist
# 30317       7 Years Before the Heist
# 30318       7 Years Before the Heist
# 30319       3 Weeks Before the Heist
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Bar chart
data['max_label'].value_counts().plot(kind='bar', color='#95bfb2')
plt.title('max_label Counts')
plt.xlabel('max_label')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns

custom_cmap = LinearSegmentedColormap.from_list("custom_pistachio", [ "#95bfb2","white"])

crosstab = pd.crosstab(data['Genres Episode 1'], data['max_label'])
sns.heatmap(crosstab, annot=True, cmap=custom_cmap, fmt='d')
plt.title('Heatmap of Genres Episode 1 vs max_label')
plt.xlabel('max_label')
plt.ylabel('Genres Episode 1')
plt.show()

# %%
# Histogram for all numerical features

data.hist(figsize=(12, 10), bins=20, color='#95bfb2', edgecolor='black')
plt.tight_layout()
plt.show()
